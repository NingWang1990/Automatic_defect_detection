# %%
from fitLatticePeaks import fitLatPeaks
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200

# %%
image = np.load('image1.npy')

# %%
plt.imshow(image)

# %%
pks = fitLatPeaks(image=image, bwf_args=(100, 8),
                gauss_args=(7, 2), min_dist=10, min_int=0.2, bound=5)
# Out:
# Fitting is 0.01 % complete!
# Fitting is 0.73 % complete!
# Fitting is 1.45 % complete!
# Fitting is 2.16 % complete!
# Fitting is 2.88 % complete!
# Fitting is 3.59 % complete!
# Fitting is 4.31 % complete!
# Fitting is 5.03 % complete!
# Fitting is 5.74 % complete!
# Fitting is 6.46 % complete!
# Fitting is 7.17 % complete!
# Fitting is 7.89 % complete!
# Fitting is 8.61 % complete!
# Fitting is 9.32 % complete!
# Fitting is 10.04 % complete!
# Fitting is 10.75 % complete!
# Fitting is 11.47 % complete!
# Fitting is 12.18 % complete!
# Fitting is 12.90 % complete!
# Fitting is 13.62 % complete!
# Fitting is 14.33 % complete!
# Fitting is 15.05 % complete!
# Fitting is 15.76 % complete!
# Fitting is 16.48 % complete!
# Fitting is 17.20 % complete!
# Fitting is 17.91 % complete!
# Fitting is 18.63 % complete!
# Fitting is 19.34 % complete!
# Fitting is 20.06 % complete!
# Fitting is 20.78 % complete!
# Fitting is 21.49 % complete!
# Fitting is 22.21 % complete!
# ...

# %%
pks = findLatPeaks(image, gauss_args=(5, 2), min_dist=3, min_int=0.01)

# %%
x = pks.x
y = pks.y

# %%
x.shape
# Out:
# (7029,)

# %%
plt.imshow(image)
plt.plot(x,y,'ro',markersize=0.4)
